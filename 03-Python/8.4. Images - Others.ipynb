# %% [markdown]
# # Scipy
#
# `pip install scipy`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bibliograpy
# - https://docs.scipy.org/doc/scipy-0.18.1/reference/misc.html

# %% [markdown]
#  --------
#
# # Scikit
#
# `pip install scikit-image`
#
# ![image.png](attachment:image.png)

# %%
from skimage import data, io, filters

image = data.coins()
# ... or any other NumPy array!
io.imshow(image)
io.show()

# %% [markdown]
# ### Bibliograpy
# - http://scikit-image.org/
